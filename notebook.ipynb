# %%
import pandas as pd

# %%
alunos = {'Nome':['Luiza', 'Maria', 'Joana'], 
          'Matricula':['001','002','003'], 
          'Nota':[9, 8, 4.5]}

#trandformar dicionario em dataframe
alunos_df = pd.DataFrame(alunos)

# %%
print(alunos_df)
# Out:
#     Nome Matricula  Nota
# 0  Luiza       001   9.0
# 1  Maria       002   8.0
# 2  Joana       003   4.5

# %%
display(alunos_df)
# Out:
#     Nome Matricula  Nota
# 0  Luiza       001   9.0
# 1  Maria       002   8.0
# 2  Joana       003   4.5

# %%
students_df = pd.read_csv("Student Mental health.csv")
display(students_df)
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
display(students_df.head(3))
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# ...

# %%
print(students_df.shape)
# Out:
# (101, 11)

# %%
display(students_df.describe())
# Out:
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000

# %%
genero = students_df['Choose your gender']
display(genero)
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3      Female
# 4        Male
#         ...
# 96     Female
# 97       Male
# 98     Female
# 99     Female
# 100      Male
# Name: Choose your gender, Length: 101, dtype: object

# %%
genero_idade = students_df[['Choose your gender', 'Age']]
display(genero_idade)
# Out:
#     Choose your gender   Age
# 0               Female  18.0
# 1                 Male  21.0
# 2                 Male  19.0
# 3               Female  22.0
# 4                 Male  23.0
# ..                 ...   ...
# 96              Female  21.0
# 97                Male  18.0
# 98              Female  19.0
# 99              Female  23.0
# 100               Male  20.0
#
# [101 rows x 2 columns]

# %%
display(students_df.loc[1])
# Out:
# Timestamp                                          8/7/2020 12:04
# Choose your gender                                           Male
# Age                                                          21.0
# What is your course?                            Islamic education
# Your current year of Study                                 year 2
# What is your CGPA?                                    3.00 - 3.49
# Marital status                                                 No
# Do you have Depression?                                        No
# Do you have Anxiety?                                          Yes
# Do you have Panic attack?                                      No
# Did you seek any specialist for a treatment?                   No
# Name: 1, dtype: object

# %%
display(students_df.loc[1:5])
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
# 5  8/7/2020 12:31               Male  19.0          Engineering
#
#   Your current year of Study What is your CGPA? Marital status  \
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
# 5                     Year 2        3.50 - 4.00             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 1                      No                  Yes                        No
# ...

# %%
display(students_df.loc[genero == 'Female'])
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 0        8/7/2020 12:02             Female  18.0          Engineering
# 3        8/7/2020 12:06             Female  22.0                 Laws
# 6        8/7/2020 12:32             Female  23.0     Pendidikan islam
# 7        8/7/2020 12:33             Female  18.0                  BCS
# 8        8/7/2020 12:35             Female  19.0      Human Resources
# ..                  ...                ...   ...                  ...
# 94  13/07/2020 17:30:44             Female  24.0                 Fiqh
# 95  13/07/2020 19:08:32             Female  18.0    Islamic Education
# 96  13/07/2020 19:56:49             Female  21.0                  BCS
# 98  13/07/2020 21:22:56             Female  19.0             Nursing
# 99  13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
#
#    Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
display(students_df.loc[genero == 'Female'].head(5))
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 6  8/7/2020 12:32             Female  23.0     Pendidikan islam
# 7  8/7/2020 12:33             Female  18.0                  BCS
# 8  8/7/2020 12:35             Female  19.0      Human Resources
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 6                     year 2       3.50 - 4.00             Yes
# 7                     year 1        3.50 - 4.00             No
# 8                     Year 2        2.50 - 2.99             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
fem_students_df = pd.DataFrame(students_df.loc[genero == 'Female'])
display(fem_students_df)
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 0        8/7/2020 12:02             Female  18.0          Engineering
# 3        8/7/2020 12:06             Female  22.0                 Laws
# 6        8/7/2020 12:32             Female  23.0     Pendidikan islam
# 7        8/7/2020 12:33             Female  18.0                  BCS
# 8        8/7/2020 12:35             Female  19.0      Human Resources
# ..                  ...                ...   ...                  ...
# 94  13/07/2020 17:30:44             Female  24.0                 Fiqh
# 95  13/07/2020 19:08:32             Female  18.0    Islamic Education
# 96  13/07/2020 19:56:49             Female  21.0                  BCS
# 98  13/07/2020 21:22:56             Female  19.0             Nursing
# 99  13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
#
#    Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
fem_students_age_course_df = pd.DataFrame(students_df.loc[genero == 'Female',['Age','What is your course?']])
display(fem_students_age_course_df)
# Out:
#      Age What is your course?
# 0   18.0          Engineering
# 3   22.0                 Laws
# 6   23.0     Pendidikan islam
# 7   18.0                  BCS
# 8   19.0      Human Resources
# ..   ...                  ...
# 94  24.0                 Fiqh
# 95  18.0    Islamic Education
# 96  21.0                  BCS
# 98  19.0             Nursing
# 99  23.0     Pendidikan Islam
#
# [75 rows x 2 columns]
